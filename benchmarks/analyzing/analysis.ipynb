# %%
import importlib
import analysis
from IPython.display import HTML, display

importlib.reload(analysis)

df = analysis.read_experiments([
  "../campaign/turbo-v1.0.1.csv",
  "../campaign/turbo.gpu.release-v1.1.0-A5000.csv",
  "../campaign/turbo.gpu.release-v1.1.1-A5000.csv",
  "../campaign/turbo.gpu.release-v1.1.2-A5000.csv",
  "../campaign/turbo.gpu.release-v1.1.3-A5000.csv",
  "../campaign/turbo.gpu.release-v1.1.4-A5000.csv",
  "../campaign/turbo.gpu.release-v1.1.5-A5000.csv",
  "../campaign/turbo.gpu.release-v1.1.6-A5000.csv",
  "../campaign/turbo.gpu.release-v1.1.7-A5000.csv",
  "../campaign/turbo.gpu.release-v1.1.0-A100.csv",
  "../campaign/turbo.gpu.release-v1.1.1-A100.csv",
  "../campaign/turbo.gpu.release-v1.1.2-A100.csv",
  "../campaign/turbo.gpu.release-v1.1.3-A100.csv",
  "../campaign/turbo.gpu.release-v1.1.6-A100.csv",
  "../campaign/turbo.gpu.release-v1.1.7-A100.csv"
  ])
# df.to_csv("test.csv", index=False)
# df = df[~(df['problem'] == "rcpsp")]
# df = df[df['problem'] == "rcpsp"]

df = analysis.benchmarks_view(df, "../benchmarking/short.csv")

analysis.plot_overall_result(df)
display(HTML(analysis.metrics_table(df[df['mzn_solver'] == "turbo.gpu.release"]).to_html()))

_ = analysis.compare_solvers_pie_chart(df, "turbo.gpu.release_1.0.1_Desktop-A5000_1024_64_256", "turbo.gpu.release_1.1.0_Desktop-A5000_1024_64_256")
# _ = analysis.compare_solvers_pie_chart(df, "turbo.gpu.release_1.1.0_Desktop-A5000_1024_64_256", "turbo.gpu.release_1.1.0_Desktop-A5000_4096_64_256")
# _ = analysis.compare_solvers_pie_chart(df, "turbo.gpu.release_1.1.0_Desktop-A5000_4096_64_256", "turbo.gpu.release_1.1.3_Desktop-A5000_4096_64_256")
# _ = analysis.compare_solvers_pie_chart(df, "turbo.gpu.release_1.1.3_Desktop-A5000_4096_64_256", "turbo.gpu.release_1.1.4_Desktop-A5000_4096_64_256")
# _ = analysis.compare_solvers_pie_chart(df, "turbo.gpu.release_1.1.3_Desktop-A5000_4096_64_256", "turbo.gpu.release_1.1.5_Desktop-A5000_4096_64_256")
# _ = analysis.compare_solvers_pie_chart(df, "turbo.gpu.release_1.1.5_Desktop-A5000_4096_64_256", "turbo.gpu.release_1.1.6_Desktop-A5000_4096_64_256")
# _ = analysis.compare_solvers_pie_chart(df, "turbo.gpu.release_1.1.6_Desktop-A5000_4096_64_256", "turbo.gpu.release_1.1.7_Desktop-A5000_4096_64_256")

# df[(df['mzn_solver'] == "turbo.gpu.release") & (df['memory_configuration'] == "store_pc_shared") & (df['eps_num_subproblems'] == 4096)]
# df[(df['mzn_solver'] == "turbo.gpu.release") & (df['problem'] == "nfc") & (df['eps_num_subproblems'] == 4096)]
# Out:
# ../campaign/turbo.gpu.release-v1.1.7-A5000.csv: 26 failed experiments using turbo.gpu.release have been removed (the faulty experiments have been stored in failed_turbo.gpu.release-v1.1.7-A5000.csv).
# ../campaign/turbo.gpu.release-v1.1.6-A100.csv: 66 failed experiments using turbo.gpu.release have been removed (the faulty experiments have been stored in failed_turbo.gpu.release-v1.1.6-A100.csv).
# ../campaign/turbo.gpu.release-v1.1.7-A100.csv: 1116 failed experiments using turbo.gpu.release have been removed (the faulty experiments have been stored in failed_turbo.gpu.release-v1.1.7-A100.csv).
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>uid</th>
#       <th>version</th>
#       <th>machine</th>
#       <th>avg_nodes_per_second</th>
#       <th>median_nodes_per_second</th>
#       <th>avg_fp_iterations_per_second</th>
#       <th>median_fp_iterations_per_second</th>
#       <th>avg_fp_iterations</th>
#       <th>median_fp_iterations</th>
#       <th>avg_propagator_mem_mb</th>
#       <th>median_propagator_mem_mb</th>
#       <th>avg_store_mem_kb</th>
#       <th>median_store_mem_kb</th>
#       <th>problem_optimal</th>
#       <th>problem_sat</th>
#       <th>problem_unknown</th>
#       <th>problem_with_store_shared</th>
#       <th>problem_with_props_shared</th>
#       <th>idle_eps_workers</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>23</th>
#       <td>turbo.gpu.release_1.1.7_Meluxina_4096_108_256_noatomics</td>
#       <td>1.1.7</td>
#       <td>Meluxina</td>
#       <td>9504.457138</td>
#       <td>7439.474353</td>
#       <td>71114.479237</td>
#       <td>48123.093512</td>
#       <td>20.632920</td>
#       <td>9.629147</td>
#       <td>7.073995</td>
#       <td>3.214200</td>
#       <td>38.002133</td>
#       <td>6.736</td>
#       <td>0</td>
#       <td>13</td>
#       <td>2</td>
#       <td>10</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>turbo.gpu.release_1.1.7_Meluxina_4096_108_256_globalmem</td>
#       <td>1.1.7</td>
#       <td>Meluxina</td>
#       <td>7427.701257</td>
#       <td>3619.879478</td>
#       <td>58201.353451</td>
#       <td>37960.637073</td>
#       <td>21.989969</td>
#       <td>11.864450</td>
#       <td>10.413292</td>
#       <td>4.333103</td>
#       <td>56.370286</td>
#       <td>16.464</td>
#       <td>0</td>
#       <td>12</td>
#       <td>2</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>turbo.gpu.release_1.1.6_Meluxina_4096_108_256</td>
#       <td>1.1.6</td>
#       <td>Meluxina</td>
#       <td>4852.076037</td>
#       <td>1202.238423</td>
#       <td>27206.883793</td>
#       <td>8305.478611</td>
#       <td>12.037605</td>
#       <td>5.627434</td>
#       <td>9.147379</td>
#       <td>8.102553</td>
#       <td>70.528267</td>
#       <td>83.900</td>
#       <td>10</td>
#       <td>18</td>
#       <td>2</td>
#       <td>10</td>
#       <td>1</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td