# %%
import importlib
import analysis
from IPython.display import HTML, display

importlib.reload(analysis)

df = analysis.read_experiments(["../campaign/turbo-v1.0.1.csv", "../campaign/turbo-v1.1.0-A5000.csv", "../campaign/turbo-v1.1.0-A100.csv"])
# df.to_csv("test.csv", index=False)
df = analysis.remove_meluxina_scaling_tests(df)
analysis.plot_overall_result(df)
display(HTML(analysis.metrics_table(df[df['configuration'] == "TurboGPU"]).to_html()))

analysis.compare_solvers_pie_chart(df, "choco.noglobal_4.10.13_Desktop-A5000", "TurboGPU_1.1.0_Meluxina_4096_108_256")
_ = analysis.compare_solvers_pie_chart(df, "TurboGPU_1.1.0_Desktop-A5000_1024_64_256", "TurboGPU_1.1.0_Meluxina_1024_108_256")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>uid</th>
#       <th>version</th>
#       <th>machine</th>
#       <th>avg_nodes_per_second</th>
#       <th>median_nodes_per_second</th>
#       <th>avg_fp_iterations</th>
#       <th>median_fp_iterations</th>
#       <th>avg_propagator_mem_mb</th>
#       <th>median_propagator_mem_mb</th>
#       <th>avg_store_mem_kb</th>
#       <th>median_store_mem_kb</th>
#       <th>idle_eps_workers</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>TurboGPU_1.1.0_Desktop-A5000_1024_64_256</td>
#       <td>1.1.0</td>
#       <td>Desktop-A5000</td>
#       <td>2422.208759</td>
#       <td>621.699819</td>
#       <td>7.293384</td>
#       <td>5.870593</td>
#       <td>12.645489</td>
#       <td>7.793582</td>
#       <td>72.289600</td>
#       <td>84.096</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>3</th>
# ...
