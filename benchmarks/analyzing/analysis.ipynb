# %%
import importlib
import analysis
from IPython.display import HTML, display

importlib.reload(analysis)

df = analysis.read_experiments(["../campaign/turbo-v1.0.1.csv", "../campaign/turbo.gpu.release-v1.1.0-A5000.csv", "../campaign/turbo.gpu.release-v1.1.1-A5000.csv", "../campaign/turbo.gpu.release-v1.1.2-A5000.csv", "../campaign/turbo.gpu.release-v1.1.3-A5000.csv", "../campaign/turbo.gpu.release-v1.1.0-A100.csv", "../campaign/turbo.gpu.release-v1.1.1-A100.csv", "../campaign/turbo.gpu.release-v1.1.2-A100.csv", "../campaign/turbo.gpu.release-v1.1.3-A100.csv"])
# df.to_csv("test.csv", index=False)
# df = analysis.remove_meluxina_scaling_tests(df)
# df = df[~(df['problem'] == "rcpsp")]
df = df[df['problem'] == "rcpsp"]
analysis.plot_overall_result(df)
display(HTML(analysis.metrics_table(df[df['mzn_solver'] == "turbo.gpu.release"]).to_html()))

analysis.compare_solvers_pie_chart(df, "org.choco.choco.noglobal_4.10.13_Desktop-A5000", "turbo.gpu.release_1.1.3_Meluxina_4096_108_256")
_ = analysis.compare_solvers_pie_chart(df, "turbo.gpu.release_1.0.1_Desktop-A5000_1024_64_256", "turbo.gpu.release_1.1.0_Desktop-A5000_4096_64_256")
_ = analysis.compare_solvers_pie_chart(df, "turbo.gpu.release_1.1.0_Desktop-A5000_4096_64_256", "turbo.gpu.release_1.1.0_Meluxina_4096_108_256")
_ = analysis.compare_solvers_pie_chart(df, "turbo.gpu.release_1.1.0_Meluxina_4096_108_256", "turbo.gpu.release_1.1.1_Meluxina_4096_108_256")
_ = analysis.compare_solvers_pie_chart(df, "turbo.gpu.release_1.1.1_Meluxina_4096_108_256", "turbo.gpu.release_1.1.2_Meluxina_4096_108_256")
_ = analysis.compare_solvers_pie_chart(df, "turbo.gpu.release_1.1.2_Meluxina_4096_108_256", "turbo.gpu.release_1.1.3_Meluxina_4096_108_256")
_ = analysis.compare_solvers_pie_chart(df, "turbo.gpu.release_1.1.1_Meluxina_4096_108_256", "turbo.gpu.release_1.1.3_Meluxina_4096_108_256")
_ = analysis.compare_solvers_pie_chart(df, "turbo.gpu.release_1.1.3_Desktop-A5000_4096_64_256", "turbo.gpu.release_1.1.3_Meluxina_4096_108_256")
_ = analysis.compare_solvers_pie_chart(df, "turbo.gpu.release_1.1.2_Desktop-A5000_4096_64_256", "turbo.gpu.release_1.1.2_Meluxina_4096_108_256")
_ = analysis.compare_solvers_pie_chart(df, "turbo.gpu.release_1.1.1_Desktop-A5000_4096_64_256", "turbo.gpu.release_1.1.1_Meluxina_4096_108_256")
_ = analysis.compare_solvers_pie_chart(df, "turbo.gpu.release_1.1.0_Desktop-A5000_4096_64_256", "turbo.gpu.release_1.1.0_Meluxina_4096_108_256")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>uid</th>
#       <th>version</th>
#       <th>machine</th>
#       <th>avg_nodes_per_second</th>
#       <th>median_nodes_per_second</th>
#       <th>avg_fp_iterations</th>
#       <th>median_fp_iterations</th>
#       <th>avg_propagator_mem_mb</th>
#       <th>median_propagator_mem_mb</th>
#       <th>avg_store_mem_kb</th>
#       <th>median_store_mem_kb</th>
#       <th>idle_eps_workers</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>14</th>
#       <td>turbo.gpu.release_1.1.3_Meluxina_4096_108_256</td>
#       <td>1.1.3</td>
#       <td>Meluxina</td>
#       <td>1013.659517</td>
#       <td>1056.591196</td>
#       <td>4.380867</td>
#       <td>3.783506</td>
#       <td>8.910164</td>
#       <td>8.616955</td>
#       <td>91.525474</td>
#       <td>91.208</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>12</th>
# ...
